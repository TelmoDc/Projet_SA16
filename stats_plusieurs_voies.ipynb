# %%
from trafic import *
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
route, vitesses = config_equidistance(20, 5)
route = np.vstack([route, route_vide(20)])

# route = np.array([[0, 0, 1, 0, -1, 0, 0, 0, 0, 0], [0, 0, 2, 0, 0, 0, 0, 0, 0, 0]])
# vitesses = {1: 3, 2: 3}

modele = ModelePlusieursVoies({1: 5, 2:5, 3:4, 4:4, 5:3}, 0.3, 0.1, 10)
traj_route, traj_vitesses = modele.trajectoire(route, vitesses, 100)

for route in traj_route:
    for lane in route:
        print("|", end="")
        for car in lane:
            if car < 0:
                print(f"{car} |", end='')
            elif car == 0:
                print("   |", end='')
            else:
                print(f" {car} |", end='')
        print()
    print()
# Out:
# | 1 |   |   |   | 2 |   |   |   | 3 |   |   |   | 4 |   |   |   | 5 |   |   |   |
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |
#
# |   | 1 |   |   |   | 2 |   |   |   | 3 |   |   |-1 |   |   |   |   | 5 |   |   |
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |
#
# |   |   | 1 |   |   |   | 2 |   |   |   | 3 |   |-2 |   |   |   |   |   |   | 5 |
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |
#
# |   | 5 |   |   | 1 |   |   | 2 |   |   | 3 |   |-3 |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |
#
# |   |   |   | 5 |   | 1 |   |   |   | 2 |   | 3 |-4 |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |
#
# |   |   |   |   |   |   |   | 1 |   |   |   |   |-5 |   |   |   |   |   |   |   |
# ...
